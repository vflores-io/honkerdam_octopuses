# %%
import polars as pl
import os

# %%
#lets read in the data I downloaded from hugging face, I start with the last 6 files
data_folder = "data/"
df1 = pl.read_parquet(os.path.join(data_folder, "train-00121-of-00127.parquet"))
df2 = pl.read_parquet(os.path.join(data_folder, "train-00122-of-00127.parquet"))
df3 = pl.read_parquet(os.path.join(data_folder, "train-00123-of-00127.parquet"))
df4 = pl.read_parquet(os.path.join(data_folder, "train-00124-of-00127.parquet"))
df5 = pl.read_parquet(os.path.join(data_folder, "train-00125-of-00127.parquet"))
df6 = pl.read_parquet(os.path.join(data_folder, "train-00126-of-00127.parquet"))

# %%
# let's take a look at the first few columns and the column names
df1.head()
# Out:
# shape: (5, 8)
# ┌────────────┬───────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ repo       ┆ issue_id  ┆ issue_numb ┆ pull_reque ┆ events    ┆ text_size ┆ content   ┆ usernames │
# │ ---        ┆ ---       ┆ er         ┆ st         ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ i64       ┆ ---        ┆ ---        ┆ list[stru ┆ i64       ┆ str       ┆ str       │
# │            ┆           ┆ i64        ┆ struct[3]  ┆ ct[8]]    ┆           ┆           ┆           │
# ╞════════════╪═══════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ kaisermann ┆ 550510104 ┆ 40         ┆ {40,"svelt ┆ [{"opened ┆ 2398      ┆ <issue_st ┆ ["kaiserm │
# │ /svelte-i1 ┆           ┆            ┆ e-i18n","k ┆ ","kaiser ┆           ┆ art><issu ┆ ann", "el │
# │ 8n         ┆           ┆            ┆ aisermann" ┆ mann",nul ┆           ┆ e_comment ┆ bourki"]  │
# │            ┆           ┆            ┆ …          ┆ l,"…      ┆           ┆ >Ti…      ┆           │
# │ TheJackson ┆ 550594847 ┆ 153        ┆ null       ┆ [{"opened ┆ 985       ┆ <issue_st ┆ ["Kevin-M │
# │ Laboratory ┆           ┆            ┆            ┆ ","Kevin- ┆           ┆ art><issu ┆ oo", "fpb │
# │ /GLASS     ┆           ┆            ┆            ┆ Moo",null ┆           ┆ e_comment ┆ arthel"]  │
# │            ┆           ┆            ┆            ┆ ,"2…      ┆           ┆ >Ti…      ┆           │
# │ jaegertrac ┆ 550687388 ┆ 854        ┆ null       ┆ [{"opened ┆ 1607      ┆ <issue_st ┆ ["jpkrohl │
# │ ing/jaeger ┆           ┆            ┆            ┆ ","yogeek ┆           ┆ art><issu ┆ ing",     │
# │ -operator  ┆           ┆            ┆            ┆ ",null,"2 ┆           ┆ e_comment ┆ "yogeek"] │
# │            ┆           ┆            ┆            ┆ 020…      ┆           ┆ >Ti…      ┆           │
# │ huda-lab/s ┆ 550969108 ┆ 2          ┆ null       ┆ [{"opened ┆ 223       ┆ <issue_st ┆ ["abdelou │
# │ ynner      ┆           ┆            ┆            ┆ ","abdelo ┆           ┆ art><issu ┆ ahab1"]   │
# │            ┆           ┆            ┆            ┆ uahab1",n ┆           ┆ e_comment ┆           │
# │            ┆           ┆            ┆            ┆ ull…      ┆           ┆ >Ti…      ┆           │
# │ SayusiAndo ┆ 551007162 ┆ 8          ┆ null       ┆ [{"opened ┆ 226       ┆ <issue_st ┆ ["SayusiA │
# │ /DigitalLi ┆           ┆            ┆            ┆ ","Sayusi ┆           ┆ art><issu ┆ ndo"]     │
# │ brary      ┆           ┆            ┆            ┆ Ando",nul ┆           ┆ e_comment ┆           │
# │            ┆           ┆            ┆            ┆ l,"…      ┆           ┆ >Ti…      ┆           │
# └────────────┴───────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %%
# let's filter out issues without pull requests
onlyPR1 = df1.filter(pl.col("pull_request")!="{null,null,null}")
onlyPR2 = df2.filter(pl.col("pull_request")!="{null,null,null}")
onlyPR3 = df3.filter(pl.col("pull_request")!="{null,null,null}")
onlyPR4 = df4.filter(pl.col("pull_request")!="{null,null,null}")
onlyPR5 = df5.filter(pl.col("pull_request")!="{null,null,null}")
onlyPR6 = df6.filter(pl.col("pull_request")!="{null,null,null}")

# %%
# let's squash it into one df
pr_df = pl.concat([onlyPR1,onlyPR2,onlyPR3,onlyPR4,onlyPR5,onlyPR6])

# %%
# that's a pretty big nice dataset
pr_df.shape
# Out:
# (478525, 8)

# %%
# to compare the Open Issues to the issues from our dataset, we extract what's between
# the first <issue comment> and second <issue comment> and save it in "issue" column
# since that's the title and the description of the issue and will be crucial in estimating the similarity between
# Open issues and issue from our dataset
pr_df
# Out:
# shape: (478_525, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ repo       ┆ issue_id   ┆ issue_numb ┆ pull_requ ┆ events    ┆ text_size ┆ content   ┆ usernames │
# │ ---        ┆ ---        ┆ er         ┆ est       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ i64        ┆ ---        ┆ ---       ┆ list[stru ┆ i64       ┆ str       ┆ str       │
# │            ┆            ┆ i64        ┆ struct[3] ┆ ct[8]]    ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ kaisermann ┆ 550510104  ┆ 40         ┆ {40,"svel ┆ [{"opened ┆ 2398      ┆ <issue_st ┆ ["kaiserm │
# │ /svelte-i1 ┆            ┆            ┆ te-i18n", ┆ ","kaiser ┆           ┆ art><issu ┆ ann", "el │
# │ 8n         ┆            ┆            ┆ "kaiserma ┆ mann",nul ┆           ┆ e_comment ┆ bourki"]  │
# │            ┆            ┆            ┆ nn"…      ┆ l,"…      ┆           ┆ >Ti…      ┆           │
# │ material-c ┆ 551064006  ┆ 9444       ┆ {9444,"ma ┆ [{"opened ┆ 355       ┆ <issue_st ┆ ["jverkoe │
# │ omponents/ ┆            ┆            ┆ terial-co ┆ ","jverko ┆           ┆ art><issu ┆ y", "brya │
# │ material-c ┆            ┆            ┆ mponents- ┆ ey",null, ┆           ┆ e_comment ┆ noltman"] │
# │ …          ┆            ┆            ┆ ios…      ┆ "20…      ┆           ┆ >Ti…      ┆           │
# │ hmcts/ccd- ┆ 551466679  ┆ 758        ┆ {758,"ccd ┆ [{"opened ┆ 601       ┆ <issue_st ┆ ["noronha │
# │ data-store ┆            ┆            ┆ -data-sto ┆ ","noronh ┆           ┆ art><issu ┆ a"]       │
# │ -api       ┆            ┆            ┆ re-api"," ┆ aa",null, ┆           ┆ e_comment ┆           │
# │            ┆            ┆            ┆ hmc…      ┆ "20…      ┆           ┆ >Ti…      ┆           │
# │ dlang/phob ┆ 551980198  ┆ 7355       ┆ {7355,"ph ┆ [{"opened ┆ 4306      ┆ <issue_st ┆ ["wilzbac │
# │ os         ┆            ┆            ┆ obos","dl ┆ ","jacob- ┆           ┆ art><issu ┆ h", "etci │
# │            ┆            ┆            ┆ ang"}     ┆ carlborg" ┆           ┆ e_comment ┆ mon",     │
# │            ┆            ┆            ┆           ┆ ,nu…      ┆           ┆ >Ti…      ┆ "Geod2…   │
# │ patternfly ┆ 552466427  ┆ 686        ┆ {686,"pat ┆ [{"opened ┆ 1995      ┆ <issue_st ┆ ["starrye │
# │ /patternfl ┆            ┆            ┆ ternfly-e ┆ ","Lyndse ┆           ┆ art><issu ┆ yez024",  │
# │ y-elements ┆            ┆            ┆ lements", ┆ yR",null, ┆           ┆ e_comment ┆ "LyndseyR │
# │            ┆            ┆            ┆ "pa…      ┆ "20…      ┆           ┆ >Ti…      ┆ "]        │
# │ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         ┆ …         │
# │ okex/excha ┆ 1187862225 ┆ 1786       ┆ {1786,"ex ┆ [{"opened ┆ 1092      ┆ <issue_st ┆ ["cwbhhjl │
# │ in         ┆            ┆            ┆ chain","o ┆ ","cwbhhj ┆           ┆ art><issu ┆ "]        │
# │            ┆            ┆            ┆ kex"}     ┆ l",null," ┆           ┆ e_comment ┆           │
# │            ┆            ┆            ┆           ┆ 202…      ┆           ┆ >Ti…      ┆           │
# │ rust-bitco ┆ 1188051396 ┆ 924        ┆ {924,"rus ┆ [{"opened ┆ 2842      ┆ <issue_st ┆ ["sanket1 │
# │ in/rust-bi ┆            ┆            ┆ t-bitcoin ┆ ","dr-orl ┆           ┆ art><issu ┆ 729", "dr │
# │ tcoin      ┆            ┆            ┆ ","rust-b ┆ ovsky",nu ┆           ┆ e_comment ┆ -orlovsky │
# │            ┆            ┆            ┆ itc…      ┆ ll,…      ┆           ┆ >Ti…      ┆ "]        │
# │ funcx-faas ┆ 1188111034 ┆ 747        ┆ {747,"fun ┆ [{"opened ┆ 427       ┆ <issue_st ┆ ["sirosen │
# │ /funcX     ┆            ┆            ┆ cX","func ┆ ","khk-gl ┆           ┆ art><issu ┆ ", "khk-g │
# │            ┆            ┆            ┆ x-faas"}  ┆ obus",nul ┆           ┆ e_comment ┆ lobus"]   │
# │            ┆            ┆            ┆           ┆ l,"…      ┆           ┆ >Ti…      ┆           │
# │ MicrosoftD ┆ 1188456644 ┆ 5640       ┆ {5640,"ms ┆ [{"opened ┆ 1248      ┆ <issue_st ┆ ["surbhig │
# │ ocs/msteam ┆            ┆            ┆ teams-doc ┆ ","surbhi ┆           ┆ art><issu ┆ upta12",  │
# │ s-docs     ┆            ┆            ┆ s","Micro ┆ gupta12", ┆           ┆ e_comment ┆ "opbld31" │
# │            ┆            ┆            ┆ sof…      ┆ nul…      ┆           ┆ >Ti…      ┆ ]         │
# │ code-dot-o ┆ 1188946570 ┆ 45600      ┆ {45600,"c ┆ [{"opened ┆ 2798      ┆ <issue_st ┆ ["annaxup │
# │ rg/code-do ┆            ┆            ┆ ode-dot-o ┆ ","annaxu ┆           ┆ art><issu ┆ hoto"]    │
# │ t-org      ┆            ┆            ┆ rg","code ┆ photo",nu ┆           ┆ e_comment ┆           │
# │            ┆            ┆            ┆ -do…      ┆ ll,…      ┆           ┆ >Ti…      ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
# regex on friday night, yeah!
import re

def extract_text(text): 
    pattern = r'<issue_comment>(.*?)<issue_comment>' 
    match = re.search(pattern, text, re.DOTALL) 
    if match: 
        return match.group(1) 
    else: 
        return None

# %%
pr_df = pr_df.with_columns([ pl.col("content").map_elements(extract_text, return_dtype=pl.Utf8).alias("issue") ])

# %%
pr_df.head()
#and it worked!
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ repo      ┆ issue_id  ┆ issue_num ┆ pull_requ ┆ … ┆ text_size ┆ content   ┆ usernames ┆ issue    │
# │ ---       ┆ ---       ┆ ber       ┆ est       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ i64       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆ i64       ┆ struct[3] ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ kaiserman ┆ 550510104 ┆ 40        ┆ {40,"svel ┆ … ┆ 2398      ┆ <issue_st ┆ ["kaiserm ┆ Title:   │
# │ n/svelte- ┆           ┆           ┆ te-i18n", ┆   ┆           ┆ art><issu ┆ ann", "el ┆ WIP - v3 │
# │ i18n      ┆           ┆           ┆ "kaiserma ┆   ┆           ┆ e_comment ┆ bourki"]  ┆ username │
# │           ┆           ┆           ┆ nn"…      ┆   ┆           ┆ >Ti…      ┆           ┆ _0:      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ material- ┆ 551064006 ┆ 9444      ┆ {9444,"ma ┆ … ┆ 355       ┆ <issue_st ┆ ["jverkoe ┆ Title:   │
# │ component ┆           ┆           ┆ terial-co ┆   ┆           ┆ art><issu ┆ y", "brya ┆ [AppBar] │
# │ s/materia ┆           ┆           ┆ mponents- ┆   ┆           ┆ e_comment ┆ noltman"] ┆ Fix      │
# │ l-c…      ┆           ┆           ┆ ios…      ┆   ┆           ┆ >Ti…      ┆           ┆ swipe to │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ g…       │
# │ hmcts/ccd ┆ 551466679 ┆ 758       ┆ {758,"ccd ┆ … ┆ 601       ┆ <issue_st ┆ ["noronha ┆ null     │
# │ -data-sto ┆           ┆           ┆ -data-sto ┆   ┆           ┆ art><issu ┆ a"]       ┆          │
# │ re-api    ┆           ┆           ┆ re-api"," ┆   ┆           ┆ e_comment ┆           ┆          │
# │           ┆           ┆           ┆ hmc…      ┆   ┆           ┆ >Ti…      ┆           ┆          │
# │ dlang/pho ┆ 551980198 ┆ 7355      ┆ {7355,"ph ┆ … ┆ 4306      ┆ <issue_st ┆ ["wilzbac ┆ Title:   │
# │ bos       ┆           ┆           ┆ obos","dl ┆   ┆           ┆ art><issu ┆ h", "etci ┆ Add      │
# │           ┆           ┆           ┆ ang"}     ┆   ┆           ┆ e_comment ┆ mon",     ┆ initial  │
# │           ┆           ┆           ┆           ┆   ┆           ┆ >Ti…      ┆ "Geod2…   ┆ support  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ for…     │
# │ patternfl ┆ 552466427 ┆ 686       ┆ {686,"pat ┆ … ┆ 1995      ┆ <issue_st ┆ ["starrye ┆ Title:   │
# │ y/pattern ┆           ┆           ┆ ternfly-e ┆   ┆           ┆ art><issu ┆ yez024",  ┆ added    │
# │ fly-eleme ┆           ┆           ┆ lements", ┆   ┆           ┆ e_comment ┆ "LyndseyR ┆ fix for  │
# │ nts       ┆           ┆           ┆ "pa…      ┆   ┆           ┆ >Ti…      ┆ "]        ┆ nav      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ prior…   │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# since I used <issue_comment> as the second delimiter it produced output only for Issues with at least one comment
# and there were some null values from issues with only titles and descriptions, so let's leave it like that
# and remove the null values
pr_df = pr_df.filter(pl.col("issue").is_not_null())
pr_df.shape
# Out:
# (414185, 9)

# %%
pr_df.columns
# Out:
# ['repo',
#  'issue_id',
#  'issue_number',
#  'pull_request',
#  'events',
#  'text_size',
#  'content',
#  'usernames',
#  'issue']

# %%
# lets now split information in "repo" column into two separate columns, specifically "parent_repo" and "child_repo"
pr_df = pr_df.with_columns(pr_df.select(pl.col("repo").str.split(by="/").list.to_struct(n_field_strategy="max_width")).unnest("repo"))

# %%
pr_df
# Out:
# shape: (414_185, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ repo      ┆ issue_id  ┆ issue_num ┆ pull_requ ┆ … ┆ usernames ┆ issue     ┆ field_0   ┆ field_1  │
# │ ---       ┆ ---       ┆ ber       ┆ est       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ i64       ┆ ---       ┆ ---       ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆ i64       ┆ struct[3] ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ kaiserman ┆ 550510104 ┆ 40        ┆ {40,"svel ┆ … ┆ ["kaiserm ┆ Title:    ┆ kaiserman ┆ svelte-i │
# │ n/svelte- ┆           ┆           ┆ te-i18n", ┆   ┆ ann", "el ┆ WIP - v3  ┆ n         ┆ 18n      │
# │ i18n      ┆           ┆           ┆ "kaiserma ┆   ┆ bourki"]  ┆ username_ ┆           ┆          │
# │           ┆           ┆           ┆ nn"…      ┆   ┆           ┆ 0:        ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ material- ┆ 551064006 ┆ 9444      ┆ {9444,"ma ┆ … ┆ ["jverkoe ┆ Title:    ┆ material- ┆ material │
# │ component ┆           ┆           ┆ terial-co ┆   ┆ y", "brya ┆ [AppBar]  ┆ component ┆ -compone │
# │ s/materia ┆           ┆           ┆ mponents- ┆   ┆ noltman"] ┆ Fix swipe ┆ s         ┆ nts-ios  │
# │ l-c…      ┆           ┆           ┆ ios…      ┆   ┆           ┆ to g…     ┆           ┆          │
# │ dlang/pho ┆ 551980198 ┆ 7355      ┆ {7355,"ph ┆ … ┆ ["wilzbac ┆ Title:    ┆ dlang     ┆ phobos   │
# │ bos       ┆           ┆           ┆ obos","dl ┆   ┆ h", "etci ┆ Add       ┆           ┆          │
# │           ┆           ┆           ┆ ang"}     ┆   ┆ mon",     ┆ initial   ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ "Geod2…   ┆ support   ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ for…      ┆           ┆          │
# │ patternfl ┆ 552466427 ┆ 686       ┆ {686,"pat ┆ … ┆ ["starrye ┆ Title:    ┆ patternfl ┆ patternf │
# │ y/pattern ┆           ┆           ┆ ternfly-e ┆   ┆ yez024",  ┆ added fix ┆ y         ┆ ly-eleme │
# │ fly-eleme ┆           ┆           ┆ lements", ┆   ┆ "LyndseyR ┆ for nav   ┆           ┆ nts      │
# │ nts       ┆           ┆           ┆ "pa…      ┆   ┆ "]        ┆ prior…    ┆           ┆          │
# │ NixOS/nix ┆ 553379763 ┆ 78253     ┆ {78253,"n ┆ … ┆ ["vbgl",  ┆ Title:    ┆ NixOS     ┆ nixpkgs  │
# │ pkgs      ┆           ┆           ┆ ixpkgs"," ┆   ┆ "jpas"]   ┆ coqPackag ┆           ┆          │
# │           ┆           ┆           ┆ NixOS"}   ┆   ┆           ┆ es.CoLoR: ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 1.4.…     ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ okta/odys ┆ 118371419 ┆ 1399      ┆ {1399,"od ┆ … ┆ ["edburye ┆ Title:    ┆ okta      ┆ odyssey  │
# │ sey       ┆ 5         ┆           ┆ yssey","o ┆   ┆ negren-ok ┆ Fix:      ┆           ┆          │
# │           ┆           ┆           ┆ kta"}     ┆   ┆ ta",      ┆ Table     ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ "jeffbe…  ┆ sort      ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ indicat…  ┆           ┆          │
# │ rust-bitc ┆ 118805139 ┆ 924       ┆ {924,"rus ┆ … ┆ ["sanket1 ┆ Title:    ┆ rust-bitc ┆ rust-bit │
# │ oin/rust- ┆ 6         ┆           ┆ t-bitcoin ┆   ┆ 729", "dr ┆ Improveme ┆ oin       ┆ coin     │
# │ bitcoin   ┆           ┆           ┆ ","rust-b ┆   ┆ -orlovsky ┆ nts to    ┆           ┆          │
# │           ┆           ┆           ┆ itc…      ┆   ┆ "]        ┆ taproot…  ┆           ┆          │
# │ funcx-faa ┆ 118811103 ┆ 747       ┆ {747,"fun ┆ … ┆ ["sirosen ┆ Title:    ┆ funcx-faa ┆ funcX    │
# │ s/funcX   ┆ 4         ┆           ┆ cX","func ┆   ┆ ", "khk-g ┆ Mild clar ┆ s         ┆          │
# │           ┆           ┆           ┆ x-faas"}  ┆   ┆ lobus"]   ┆ ification ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ of d…     ┆           ┆          │
# │ Microsoft ┆ 118845664 ┆ 5640      ┆ {5640,"ms ┆ … ┆ ["surbhig ┆ Title:    ┆ Microsoft ┆ msteams- │
# │ Docs/mste ┆ 4         ┆           ┆ teams-doc ┆   ┆ upta12",  ┆ Live      ┆ Docs      ┆ docs     │
# │ ams-docs  ┆           ┆           ┆ s","Micro ┆   ┆ "opbld31" ┆ username_ ┆           ┆          │
# │           ┆           ┆           ┆ sof…      ┆   ┆ ]         ┆ 0:        ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ code-dot- ┆ 118894657 ┆ 45600     ┆ {45600,"c ┆ … ┆ ["annaxup ┆ Title:    ┆ code-dot- ┆ code-dot │
# │ org/code- ┆ 0         ┆           ┆ ode-dot-o ┆   ┆ hoto"]    ┆ adding    ┆ org       ┆ -org     │
# │ dot-org   ┆           ┆           ┆ rg","code ┆   ┆           ┆ checks    ┆           ┆          │
# │           ┆           ┆           ┆ -do…      ┆   ┆           ┆ that      ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ addr…     ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
pr_df = pr_df.rename({"field_0": "parent_repo", "field_1": "child_repo"})

# %%
pr_df["parent_repo"].value_counts(sort=True)
# Out:
# shape: (58_574, 2)
# ┌──────────────────┬───────┐
# │ parent_repo      ┆ count │
# │ ---              ┆ ---   │
# │ str              ┆ u32   │
# ╞══════════════════╪═══════╡
# │ apache           ┆ 8924  │
# │ kubernetes       ┆ 4527  │
# │ MicrosoftDocs    ┆ 4115  │
# │ NixOS            ┆ 4103  │
# │ Azure            ┆ 3799  │
# │ …                ┆ …     │
# │ webview          ┆ 1     │
# │ DevShiftTeam     ┆ 1     │
# │ geoffrich        ┆ 1     │
# │ single-cell-data ┆ 1     │
# │ kvas-it          ┆ 1     │
# └──────────────────┴───────┘

# %%
#let's filter for columns that we will use in the model
pr_df = pr_df.select(
    ['repo',
     'parent_repo',
     'child_repo',
     'issue_id',
     'issue_number',
     'issue',
     'text_size',
     'usernames',
    ])
pr_df
# Out:
# shape: (414_185, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ repo       ┆ parent_rep ┆ child_repo ┆ issue_id  ┆ issue_num ┆ issue     ┆ text_size ┆ usernames │
# │ ---        ┆ o          ┆ ---        ┆ ---       ┆ ber       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ ---        ┆ str        ┆ i64       ┆ ---       ┆ str       ┆ i64       ┆ str       │
# │            ┆ str        ┆            ┆           ┆ i64       ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ kaisermann ┆ kaisermann ┆ svelte-i18 ┆ 550510104 ┆ 40        ┆ Title:    ┆ 2398      ┆ ["kaiserm │
# │ /svelte-i1 ┆            ┆ n          ┆           ┆           ┆ WIP - v3  ┆           ┆ ann", "el │
# │ 8n         ┆            ┆            ┆           ┆           ┆ username_ ┆           ┆ bourki"]  │
# │            ┆            ┆            ┆           ┆           ┆ 0:        ┆           ┆           │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆           │
# │ material-c ┆ material-c ┆ material-c ┆ 551064006 ┆ 9444      ┆ Title:    ┆ 355       ┆ ["jverkoe │
# │ omponents/ ┆ omponents  ┆ omponents- ┆           ┆           ┆ [AppBar]  ┆           ┆ y", "brya │
# │ material-c ┆            ┆ ios        ┆           ┆           ┆ Fix swipe ┆           ┆ noltman"] │
# │ …          ┆            ┆            ┆           ┆           ┆ to g…     ┆           ┆           │
# │ dlang/phob ┆ dlang      ┆ phobos     ┆ 551980198 ┆ 7355      ┆ Title:    ┆ 4306      ┆ ["wilzbac │
# │ os         ┆            ┆            ┆           ┆           ┆ Add       ┆           ┆ h", "etci │
# │            ┆            ┆            ┆           ┆           ┆ initial   ┆           ┆ mon",     │
# │            ┆            ┆            ┆           ┆           ┆ support   ┆           ┆ "Geod2…   │
# │            ┆            ┆            ┆           ┆           ┆ for…      ┆           ┆           │
# │ patternfly ┆ patternfly ┆ patternfly ┆ 552466427 ┆ 686       ┆ Title:    ┆ 1995      ┆ ["starrye │
# │ /patternfl ┆            ┆ -elements  ┆           ┆           ┆ added fix ┆           ┆ yez024",  │
# │ y-elements ┆            ┆            ┆           ┆           ┆ for nav   ┆           ┆ "LyndseyR │
# │            ┆            ┆            ┆           ┆           ┆ prior…    ┆           ┆ "]        │
# │ NixOS/nixp ┆ NixOS      ┆ nixpkgs    ┆ 553379763 ┆ 78253     ┆ Title:    ┆ 2544      ┆ ["vbgl",  │
# │ kgs        ┆            ┆            ┆           ┆           ┆ coqPackag ┆           ┆ "jpas"]   │
# │            ┆            ┆            ┆           ┆           ┆ es.CoLoR: ┆           ┆           │
# │            ┆            ┆            ┆           ┆           ┆ 1.4.…     ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         ┆ …         │
# │ okta/odyss ┆ okta       ┆ odyssey    ┆ 118371419 ┆ 1399      ┆ Title:    ┆ 431       ┆ ["edburye │
# │ ey         ┆            ┆            ┆ 5         ┆           ┆ Fix:      ┆           ┆ negren-ok │
# │            ┆            ┆            ┆           ┆           ┆ Table     ┆           ┆ ta",      │
# │            ┆            ┆            ┆           ┆           ┆ sort      ┆           ┆ "jeffbe…  │
# │            ┆            ┆            ┆           ┆           ┆ indicat…  ┆           ┆           │
# │ rust-bitco ┆ rust-bitco ┆ rust-bitco ┆ 118805139 ┆ 924       ┆ Title:    ┆ 2842      ┆ ["sanket1 │
# │ in/rust-bi ┆ in         ┆ in         ┆ 6         ┆           ┆ Improveme ┆           ┆ 729", "dr │
# │ tcoin      ┆            ┆            ┆           ┆           ┆ nts to    ┆           ┆ -orlovsky │
# │            ┆            ┆            ┆           ┆           ┆ taproot…  ┆           ┆ "]        │
# │ funcx-faas ┆ funcx-faas ┆ funcX      ┆ 118811103 ┆ 747       ┆ Title:    ┆ 427       ┆ ["sirosen │
# │ /funcX     ┆            ┆            ┆ 4         ┆           ┆ Mild clar ┆           ┆ ", "khk-g │
# │            ┆            ┆            ┆           ┆           ┆ ification ┆           ┆ lobus"]   │
# │            ┆            ┆            ┆           ┆           ┆ of d…     ┆           ┆           │
# │ MicrosoftD ┆ MicrosoftD ┆ msteams-do ┆ 118845664 ┆ 5640      ┆ Title:    ┆ 1248      ┆ ["surbhig │
# │ ocs/msteam ┆ ocs        ┆ cs         ┆ 4         ┆           ┆ Live      ┆           ┆ upta12",  │
# │ s-docs     ┆            ┆            ┆           ┆           ┆ username_ ┆           ┆ "opbld31" │
# │            ┆            ┆            ┆           ┆           ┆ 0:        ┆           ┆ ]         │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆           │
# │ code-dot-o ┆ code-dot-o ┆ code-dot-o ┆ 118894657 ┆ 45600     ┆ Title:    ┆ 2798      ┆ ["annaxup │
# │ rg/code-do ┆ rg         ┆ rg         ┆ 0         ┆           ┆ adding    ┆           ┆ hoto"]    │
# │ t-org      ┆            ┆            ┆           ┆           ┆ checks    ┆           ┆           │
# │            ┆            ┆            ┆           ┆           ┆ that      ┆           ┆           │
# │            ┆            ┆            ┆           ┆           ┆ addr…     ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
#SO we have just "usernames" that take part in "events" and "content", so I assume that the first name in "usernames" is the person
#who created the issue, and the last one who made the PR (although in practice thats the person who merged the PR)
#anyway in real case scenario we would have to find out which name comes from the author of Pull Request
#and would have to call the github API for data from that user
#to simplify the things let's just turn the user names into labels
#and join the labels with index of the kaggle dataset with users info, this way we can quickly mock the process of calling the Github repo for real user data

pr_df = pr_df.with_columns(pl.col("usernames").str.replace_all("\[","").str.replace_all("\]","").str.replace_all("\"","").str.split(by=","))
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\['
# <>:8: SyntaxWarning: invalid escape sequence '\]'
# <>:8: SyntaxWarning: invalid escape sequence '\['
# <>:8: SyntaxWarning: invalid escape sequence '\]'
# /var/folders/rx/9sb4r21x61798rxmm_5ds91c0000gn/T/ipykernel_38669/3368682134.py:8: SyntaxWarning: invalid escape sequence '\['
#   pr_df = pr_df.with_columns(pl.col("usernames").str.replace_all("\[","").str.replace_all("\]","").str.replace_all("\"","").str.split(by=","))
# /var/folders/rx/9sb4r21x61798rxmm_5ds91c0000gn/T/ipykernel_38669/3368682134.py:8: SyntaxWarning: invalid escape sequence '\]'
#   pr_df = pr_df.with_columns(pl.col("usernames").str.replace_all("\[","").str.replace_all("\]","").str.replace_all("\"","").str.split(by=","))

# %%
pr_df = pr_df.with_columns(users = pl.col("usernames").list.last())

# %%
pr_df["users"].value_counts(sort=True).shape
# Out:
# (176861, 2)

# %%
pr_df
# Out:
# shape: (414_185, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ repo      ┆ parent_re ┆ child_rep ┆ issue_id  ┆ … ┆ issue     ┆ text_size ┆ usernames ┆ users    │
# │ ---       ┆ po        ┆ o         ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ ---       ┆ ---       ┆ i64       ┆   ┆ str       ┆ i64       ┆ list[str] ┆ str      │
# │           ┆ str       ┆ str       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ kaiserman ┆ kaiserman ┆ svelte-i1 ┆ 550510104 ┆ … ┆ Title:    ┆ 2398      ┆ ["kaiserm ┆ elbourki │
# │ n/svelte- ┆ n         ┆ 8n        ┆           ┆   ┆ WIP - v3  ┆           ┆ ann", "   ┆          │
# │ i18n      ┆           ┆           ┆           ┆   ┆ username_ ┆           ┆ elbourki" ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 0:        ┆           ┆ ]         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ material- ┆ material- ┆ material- ┆ 551064006 ┆ … ┆ Title:    ┆ 355       ┆ ["jverkoe ┆ bryanolt │
# │ component ┆ component ┆ component ┆           ┆   ┆ [AppBar]  ┆           ┆ y", " bry ┆ man      │
# │ s/materia ┆ s         ┆ s-ios     ┆           ┆   ┆ Fix swipe ┆           ┆ anoltman" ┆          │
# │ l-c…      ┆           ┆           ┆           ┆   ┆ to g…     ┆           ┆ ]         ┆          │
# │ dlang/pho ┆ dlang     ┆ phobos    ┆ 551980198 ┆ … ┆ Title:    ┆ 4306      ┆ ["wilzbac ┆ jacob-ca │
# │ bos       ┆           ┆           ┆           ┆   ┆ Add       ┆           ┆ h", "     ┆ rlborg   │
# │           ┆           ┆           ┆           ┆   ┆ initial   ┆           ┆ etcimon", ┆          │
# │           ┆           ┆           ┆           ┆   ┆ support   ┆           ┆ … " j…    ┆          │
# │           ┆           ┆           ┆           ┆   ┆ for…      ┆           ┆           ┆          │
# │ patternfl ┆ patternfl ┆ patternfl ┆ 552466427 ┆ … ┆ Title:    ┆ 1995      ┆ ["starrye ┆ LyndseyR │
# │ y/pattern ┆ y         ┆ y-element ┆           ┆   ┆ added fix ┆           ┆ yez024",  ┆          │
# │ fly-eleme ┆           ┆ s         ┆           ┆   ┆ for nav   ┆           ┆ " Lyndsey ┆          │
# │ nts       ┆           ┆           ┆           ┆   ┆ prior…    ┆           ┆ R"]       ┆          │
# │ NixOS/nix ┆ NixOS     ┆ nixpkgs   ┆ 553379763 ┆ … ┆ Title:    ┆ 2544      ┆ ["vbgl",  ┆  jpas    │
# │ pkgs      ┆           ┆           ┆           ┆   ┆ coqPackag ┆           ┆ " jpas"]  ┆          │
# │           ┆           ┆           ┆           ┆   ┆ es.CoLoR: ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 1.4.…     ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ okta/odys ┆ okta      ┆ odyssey   ┆ 118371419 ┆ … ┆ Title:    ┆ 431       ┆ ["edburye ┆ jeffbels │
# │ sey       ┆           ┆           ┆ 5         ┆   ┆ Fix:      ┆           ┆ negren-ok ┆ er-okta  │
# │           ┆           ┆           ┆           ┆   ┆ Table     ┆           ┆ ta", "    ┆          │
# │           ┆           ┆           ┆           ┆   ┆ sort      ┆           ┆ jeffb…    ┆          │
# │           ┆           ┆           ┆           ┆   ┆ indicat…  ┆           ┆           ┆          │
# │ rust-bitc ┆ rust-bitc ┆ rust-bitc ┆ 118805139 ┆ … ┆ Title:    ┆ 2842      ┆ ["sanket1 ┆ dr-orlov │
# │ oin/rust- ┆ oin       ┆ oin       ┆ 6         ┆   ┆ Improveme ┆           ┆ 729", "   ┆ sky      │
# │ bitcoin   ┆           ┆           ┆           ┆   ┆ nts to    ┆           ┆ dr-orlovs ┆          │
# │           ┆           ┆           ┆           ┆   ┆ taproot…  ┆           ┆ ky"]      ┆          │
# │ funcx-faa ┆ funcx-faa ┆ funcX     ┆ 118811103 ┆ … ┆ Title:    ┆ 427       ┆ ["sirosen ┆ khk-glob │
# │ s/funcX   ┆ s         ┆           ┆ 4         ┆   ┆ Mild clar ┆           ┆ ", " khk- ┆ us       │
# │           ┆           ┆           ┆           ┆   ┆ ification ┆           ┆ globus"]  ┆          │
# │           ┆           ┆           ┆           ┆   ┆ of d…     ┆           ┆           ┆          │
# │ Microsoft ┆ Microsoft ┆ msteams-d ┆ 118845664 ┆ … ┆ Title:    ┆ 1248      ┆ ["surbhig ┆  opbld31 │
# │ Docs/mste ┆ Docs      ┆ ocs       ┆ 4         ┆   ┆ Live      ┆           ┆ upta12",  ┆          │
# │ ams-docs  ┆           ┆           ┆           ┆   ┆ username_ ┆           ┆ "         ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 0:        ┆           ┆ opbld31"] ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ code-dot- ┆ code-dot- ┆ code-dot- ┆ 118894657 ┆ … ┆ Title:    ┆ 2798      ┆ ["annaxup ┆ annaxuph │
# │ org/code- ┆ org       ┆ org       ┆ 0         ┆   ┆ adding    ┆           ┆ hoto"]    ┆ oto      │
# │ dot-org   ┆           ┆           ┆           ┆   ┆ checks    ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ that      ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ addr…     ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
pr_df = pr_df.with_columns(pl.col("users").map_batches(le.fit_transform).alias("mock_number"))
pr_df.head()
# Out:
# shape: (5, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ repo      ┆ parent_re ┆ child_rep ┆ issue_id  ┆ … ┆ text_size ┆ usernames ┆ users     ┆ mock_num │
# │ ---       ┆ po        ┆ o         ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ber      │
# │ str       ┆ ---       ┆ ---       ┆ i64       ┆   ┆ i64       ┆ list[str] ┆ str       ┆ ---      │
# │           ┆ str       ┆ str       ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ kaiserman ┆ kaiserman ┆ svelte-i1 ┆ 550510104 ┆ … ┆ 2398      ┆ ["kaiserm ┆  elbourki ┆ 52812    │
# │ n/svelte- ┆ n         ┆ 8n        ┆           ┆   ┆           ┆ ann", "   ┆           ┆          │
# │ i18n      ┆           ┆           ┆           ┆   ┆           ┆ elbourki" ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ ]         ┆           ┆          │
# │ material- ┆ material- ┆ material- ┆ 551064006 ┆ … ┆ 355       ┆ ["jverkoe ┆ bryanoltm ┆ 38978    │
# │ component ┆ component ┆ component ┆           ┆   ┆           ┆ y", " bry ┆ an        ┆          │
# │ s/materia ┆ s         ┆ s-ios     ┆           ┆   ┆           ┆ anoltman" ┆           ┆          │
# │ l-c…      ┆           ┆           ┆           ┆   ┆           ┆ ]         ┆           ┆          │
# │ dlang/pho ┆ dlang     ┆ phobos    ┆ 551980198 ┆ … ┆ 4306      ┆ ["wilzbac ┆ jacob-car ┆ 66742    │
# │ bos       ┆           ┆           ┆           ┆   ┆           ┆ h", "     ┆ lborg     ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ etcimon", ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ … " j…    ┆           ┆          │
# │ patternfl ┆ patternfl ┆ patternfl ┆ 552466427 ┆ … ┆ 1995      ┆ ["starrye ┆  LyndseyR ┆ 14002    │
# │ y/pattern ┆ y         ┆ y-element ┆           ┆   ┆           ┆ yez024",  ┆           ┆          │
# │ fly-eleme ┆           ┆ s         ┆           ┆   ┆           ┆ " Lyndsey ┆           ┆          │
# │ nts       ┆           ┆           ┆           ┆   ┆           ┆ R"]       ┆           ┆          │
# │ NixOS/nix ┆ NixOS     ┆ nixpkgs   ┆ 553379763 ┆ … ┆ 2544      ┆ ["vbgl",  ┆  jpas     ┆ 72876    │
# │ pkgs      ┆           ┆           ┆           ┆   ┆           ┆ " jpas"]  ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
#TODO: join the pr_df with github users dataset from kaggle
#create a dataset of "available" Good First Issues - we can mock also this dataset
#instead of calling github API for current/open Good First Issues, we can just re-use the data from the datasets we used so far
#build model that will compare New Users to Old Users
#build model comparing Old Issues with Open Issues

# %%
pr_df.write_parquet("data/intermediate_data/pr_df.parquet")
pr_df.shape
# Out:
# (414185, 10)
